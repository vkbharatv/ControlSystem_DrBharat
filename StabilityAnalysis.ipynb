# %%
import control as cs
import numpy as np
import matplotlib.pyplot as plt

# cs.config.use_matlab_defaults()

# %%
s = cs.tf("s")
G = 1 / (s * (s + 1) * (s + 2))
print(G)

# cs.rlocus(G)
cs.bode_plot(G, display_margins=True)
figure, ax = plt.subplots()
y, t = cs.step_response(G)
plt.plot(t, y)
# Out:
# <TransferFunction>: sys[72]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#           1
#   -----------------
#   s^3 + 3 s^2 + 2 s
